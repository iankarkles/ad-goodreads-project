# %%
import pandas as pd
from faker import Faker

# %%
df_rating = pd.read_csv('CSV Files/ratings_with_date.csv')
df_rating.head()
# Out:
#    user_id  book_id  rating        date
# 0        1      258       5  2011-03-08
# 1        2     4081       4  2014-02-28
# 2        2      260       5  2012-11-26
# 3        2     9296       5  2019-05-29
# 4        2     2318       3  2018-12-28

# %%
fake = Faker()

col_ids =  df_rating['user_id'].unique()
col_ids =  pd.DataFrame(col_ids)
col_ids.rename(columns={0:'user_id'}, inplace=True)
col_ids['username'] = col_ids.apply(lambda x: fake.unique.user_name(), axis=1)
col_ids['sex'] = col_ids.apply(lambda x:fake.bothify(text='?', letters='MF'), axis=1)
col_ids['name'] = col_ids.apply(lambda x: fake.unique.name(), axis=1)
col_ids['email'] = col_ids.apply(lambda x: fake.unique.email(), axis=1)
col_ids['birthdate'] = col_ids.apply(lambda x: fake.date_of_birth(tzinfo=None, minimum_age=23, maximum_age=90), axis=1)
col_ids['address'] = col_ids.apply(lambda x: fake.unique.address(), axis=1)
col_ids['phone_number'] = col_ids.apply(lambda x: fake.unique.phone_number(), axis=1)
#col_ids.set_index(user_id, inplace=True)

# %%
#col_ids.set_index('user_id', inplace=True)

# %%
col_ids
# Out:
#        user_id       username sex            name  \
# 0            1         hhenry   M      Jack Perez
# 1            2        bbarnes   F  Valerie Becker
# 2            4          jlevy   F  Christine Shea
# 3            6  antonioparker   M  Vanessa Garcia
# 4            8       carmen33   F  Kathryn Hester
# ...        ...            ...  ..             ...
# 53419    47704      laneemily   F   Troy Richmond
# 53420    51115          gruiz   F  Jacob Mcdonald
# 53421    27329  leonardriddle   M  Sean Contreras
# 53422    33111       nicole41   M    Morgan Davis
# 53423    49802    maryfreeman   F  Tanya Guerrero
#
#                               email   birthdate  \
# 0      brandonschneider@example.net  1941-03-30
# 1                owoods@example.net  1973-01-02
# 2                jose51@example.net  1999-09-24
# 3           michaelryan@example.com  1976-08-26
# 4           peterwalker@example.com  1938-05-05
# ...                             ...         ...
# 53419     christopher64@example.com  1933-08-14
# 53420       jamiemendez@example.org  1978-04-07
# 53421     stonekristine@example.net  1964-10-03
# 53422          robert68@example.org  1952-07-22
# 53423           aturner@example.com  1968-06-11
#
#                                                  address          phone_number
# 0         77309 Fernandez Plains\nPort Matthew, DC 51456      839.476.8003x157
# 1             600 Mary Ramp\nWest Sabrinahaven, NC 09011  +1-310-944-7550x4474
# 2           8842 Moore Forges\nWest Josephbury, VA 41255  +1-758-572-4126x9955
# 3      4807 Jose Corners Suite 282\nPort Carlaside, F...         (530)720-1957
# 4         417 Friedman Field\nLake Bradleybury, MD 77837     (524)663-1600x243
# ...                                                  ...                   ...
# 53419  976 Hancock Circles Apt. 799\nEast Neilshire, ...    193-295-2494x21272
# 53420            819 Darlene Harbor\nShaneport, GU 86397      001-994-339-2032
# 53421  60436 Black Avenue Suite 824\nWest Destinymout...          565.401.1680
# 53422  09181 Terry Harbors Suite 273\nCharlesfurt, NE...      257-871-5154x694
# 53423           992 Laura Ridge\nJohnnychester, AK 53122      830-538-2686x027
#
# [53424 rows x 8 columns]

# %%
col_ids['username'].value_counts()
# Out:
# hhenry             1
# victoria15         1
# gary91             1
# dana05             1
# lisali             1
#                   ..
# mitchellvanessa    1
# tiffanysmith       1
# randyweeks         1
# brenda48           1
# maryfreeman        1
# Name: username, Length: 53424, dtype: int64

# %%
col_ids.to_csv('CSV Files/user_2.csv')
