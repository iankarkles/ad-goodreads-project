# %%
import pandas as pd
from faker import Faker

# %%
df_rating = pd.read_csv('ratings.csv')
df_rating.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
fake = Faker()

col_ids =  df_rating['user_id'].unique()
col_ids =  pd.DataFrame(col_ids)
col_ids.rename(columns={0:'user_id'}, inplace=True)
col_ids['username'] = col_ids.apply(lambda x: fake.unique.user_name(), axis=1)
col_ids['sex'] = col_ids.apply(lambda x:fake.bothify(text='?', letters='MF'), axis=1)
col_ids['name'] = col_ids.apply(lambda x: fake.unique.name(), axis=1)
col_ids['email'] = col_ids.apply(lambda x: fake.unique.email(), axis=1)
col_ids['SSN'] = col_ids.apply(lambda x: fake.unique.ssn(), axis=1)
col_ids['address'] = col_ids.apply(lambda x: fake.unique.address(), axis=1)
col_ids['phone_number'] = col_ids.apply(lambda x: fake.unique.phone_number(), axis=1)
#col_ids.set_index(user_id, inplace=True)

# %%
col_ids.set_index('user_id', inplace=True)

# %%
col_ids
# Out:
#                    username sex              name  \
# user_id
# 1            hernandezsteve   F  Andrew Stevenson
# 2                     xcook   F      Kevin Obrien
# 4                   cwilcox   F      Sandra Payne
# 6                    ibaker   M      Laura Acosta
# 8                 charles64   M     April Sanchez
# ...                     ...  ..               ...
# 47704             brandon09   F     Carolyn Woods
# 51115                sara67   F      Richard Hill
# 27329    jacquelineanderson   F       Stacy Brown
# 33111              trevor10   M    Kevin Atkinson
# 49802     pattersonkimberly   F     Jeffrey Baird
#
#                                  email          SSN  \
# user_id
# 1             robertramsey@example.com  058-41-7113
# 2             andreasutton@example.net  530-12-5372
# 4                 fcalhoun@example.com  841-58-8647
# 6        christophermiller@example.com  153-72-1111
# 8             ricelorraine@example.com  638-25-9102
# ...                                ...          ...
# 47704              emalone@example.net  524-41-1410
# 51115             mikeberg@example.org  184-66-9626
# 27329        bradleybrewer@example.org  178-09-9109
# 33111      christinacooper@example.org  796-99-4634
# 49802         stewartapril@example.net  028-09-7628
#
#                                                    address  \
# user_id
# 1        7558 Meza Extensions\nNorth Alexandershire, ND...
# 2        50117 John Springs Suite 361\nWest Matthewton,...
# 4                   6633 Sean Fort\nNicholasfort, LA 78178
# 6        23720 Flores Expressway Suite 231\nNicholsland...
# 8        2855 Merritt Locks Suite 644\nEast Andrea, MH ...
# ...                                                    ...
# 47704                     PSC 7439, Box 8946\nAPO AA 51127
# 51115    69598 Whitney Hills Apt. 073\nChrisville, GU 7...
# 27329    59652 George View Apt. 033\nEdwardsborough, MT...
# 33111                26565 Soto Ferry\nLewisport, GA 17997
# 49802            848 Butler Cliff\nWest Courtney, WA 01921
#
#                   phone_number
# user_id
# 1              +1-321-850-5077
# 2           940.717.0383x24448
# 4                 142.941.6624
# 6                 374-409-6279
# 8         001-202-741-0687x719
# ...                        ...
# 47704            (167)790-7331
# 51115         965-598-4259x065
# 27329             139-091-4336
# 33111    001-782-657-1423x9442
# 49802    001-312-618-0381x4662
#
# [53424 rows x 7 columns]

# %%
col_ids['username'].value_counts()
# Out:
# wking              1
# matthewcain        1
# peterrichardson    1
# alexis64           1
# flloyd             1
#                   ..
# frankhaley         1
# cramirez           1
# alice71            1
# higginstiffany     1
# cory92             1
# Name: username, Length: 53424, dtype: int64
